# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import scipy.stats as sts
# %matplotlib inline

# %%
a = 0
sigma = 1
N = 10000
norm_rv = sts.norm(a, sigma)
sample = norm_rv.rvs(N)
x = np.linspace(-4,4,100)
cdf = norm_rv.cdf(x)

# %% [markdown]
# Создадим функцию, которая будет для некоторого n строить эмпирическую функцию (красным цветом) и функцию распределения (синим)

# %%
def empire(siz):
    plt.figure(figsize=(15, 8))
    plt.plot(x, cdf, label='theoretical CDF', alpha = 0.2)
    arr = ECDF(sample[0 : siz + 1])
    plt.plot(arr.x, arr.y, 'r', label='ECDF', alpha = 0.8)

    plt.ylabel('$f(x)$')
    plt.xlabel('$x$')
    plt.legend(loc='upper left')

# %%
empire(10)

# %%
empire(25)

# %%
empire(50)

# %%
empire(100)

# %%
empire(500)

# %%
empire(1000)

# %%
empire(5000)

# %%
empire(N)

# %% [markdown]
# Посчитаем значение D(n)= sup|Fn(x) - F(x)|

# %%
arr = ECDF(sample[0 : n + 1]) 
cdf = norm_rv.cdf(arr.x)
sup = [np.max(np.abs(ECDF(sample[0 : n + 1]).y - norm_rv.cdf(ECDF(sample[0 : n + 1]).x))) for n in range (N)]

# %%
x_arr = range(N)
plt.figure(figsize=(15, 4))
plt.plot(x_arr, sup)
plt.ylabel('$D(n)$')
plt.xlabel('$n$')
plt.ylim([0, 0.11])
# Out:
# (0, 0.11)
